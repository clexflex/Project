# %%
pip install speechrecognition
# Out:
# Requirement already satisfied: speechrecognition in /Users/yashraj/opt/anaconda3/lib/python3.9/site-packages (3.10.1)
# Requirement already satisfied: typing-extensions in /Users/yashraj/opt/anaconda3/lib/python3.9/site-packages (from speechrecognition) (4.3.0)
# Requirement already satisfied: requests>=2.26.0 in /Users/yashraj/opt/anaconda3/lib/python3.9/site-packages (from speechrecognition) (2.28.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/yashraj/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.26.0->speechrecognition) (2.10)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/yashraj/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.26.0->speechrecognition) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/yashraj/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.26.0->speechrecognition) (2022.9.24)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/yashraj/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.26.0->speechrecognition) (1.26.11)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pyaudio
# Out:
# Requirement already satisfied: pyaudio in /Users/yashraj/opt/anaconda3/lib/python3.9/site-packages (0.2.14)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pyttsx3
# Out:
# Collecting pyttsx3
#   Using cached pyttsx3-2.90-py3-none-any.whl (39 kB)
# Collecting pyobjc>=2.4
#   Using cached pyobjc-10.1-py3-none-any.whl (4.0 kB)
# Collecting pyobjc-framework-ScriptingBridge==10.1
#   Using cached pyobjc_framework_ScriptingBridge-10.1-cp36-abi3-macosx_10_9_x86_64.whl (6.5 kB)
# Collecting pyobjc-framework-BusinessChat==10.1
#   Using cached pyobjc_framework_BusinessChat-10.1-py2.py3-none-any.whl (3.0 kB)
# Collecting pyobjc-framework-ColorSync==10.1
#   Using cached pyobjc_framework_ColorSync-10.1-py2.py3-none-any.whl (5.7 kB)
# Collecting pyobjc-framework-SyncServices==10.1
#   Using cached pyobjc_framework_SyncServices-10.1-cp36-abi3-macosx_10_9_x86_64.whl (10 kB)
# Collecting pyobjc-framework-MetricKit==10.1
#   Using cached pyobjc_framework_MetricKit-10.1-cp39-cp39-macosx_10_9_universal2.whl (8.8 kB)
# Collecting pyobjc-framework-NaturalLanguage==10.1
#   Using cached pyobjc_framework_NaturalLanguage-10.1-py2.py3-none-any.whl (4.8 kB)
# Collecting pyobjc-framework-UserNotificationsUI==10.1
#   Using cached pyobjc_framework_UserNotificationsUI-10.1-py2.py3-none-any.whl (3.5 kB)
# Collecting pyobjc-framework-CoreMedia==10.1
#   Downloading pyobjc_framework_CoreMedia-10.1-cp39-cp39-macosx_10_9_universal2.whl (30 kB)
# Collecting pyobjc-framework-MetalKit==10.1
#   Using cached pyobjc_framework_MetalKit-10.1-cp36-abi3-macosx_10_9_x86_64.whl (6.5 kB)
# Collecting pyobjc-framework-CoreML==10.1
#   Using cached pyobjc_framework_CoreML-10.1-cp36-abi3-macosx_10_9_x86_64.whl (8.6 kB)
# Collecting pyobjc-framework-PhotosUI==10.1
#   Using cached pyobjc_framework_PhotosUI-10.1-cp36-abi3-macosx_10_9_x86_64.whl (8.4 kB)
# Collecting pyobjc-framework-CoreAudioKit==10.1
#   Using cached pyobjc_framework_CoreAudioKit-10.1-cp36-abi3-macosx_10_9_x86_64.whl (5.5 kB)
# Collecting pyobjc-framework-AdServices==10.1
#   Using cached pyobjc_framework_AdServices-10.1-py2.py3-none-any.whl (3.1 kB)
# Collecting pyobjc-framework-WebKit==10.1
#   Using cached pyobjc_framework_WebKit-10.1-cp36-abi3-macosx_10_9_x86_64.whl (32 kB)
# Collecting pyobjc-framework-ServiceManagement==10.1
#   Using cached pyobjc_framework_ServiceManagement-10.1-py2.py3-none-any.whl (5.0 kB)
# Collecting pyobjc-framework-libdispatch==10.1
#   Using cached pyobjc_framework_libdispatch-10.1-cp39-cp39-macosx_10_9_universal2.whl (21 kB)
# Collecting pyobjc-framework-MetalPerformanceShadersGraph==10.1
#   Using cached pyobjc_framework_MetalPerformanceShadersGraph-10.1-py2.py3-none-any.whl (5.8 kB)
# Collecting pyobjc-framework-AutomaticAssessmentConfiguration==10.1
#   Using cached pyobjc_framework_AutomaticAssessmentConfiguration-10.1-cp36-abi3-macosx_10_9_x86_64.whl (6.5 kB)
# Collecting pyobjc-framework-SafetyKit==10.1
#   Using cached pyobjc_framework_SafetyKit-10.1-cp36-abi3-macosx_10_9_x86_64.whl (5.9 kB)
# Collecting pyobjc-framework-AppTrackingTransparency==10.1
#   Using cached pyobjc_framework_AppTrackingTransparency-10.1-py2.py3-none-any.whl (3.4 kB)
# Collecting pyobjc-framework-LocalAuthenticationEmbeddedUI==10.1
#   Using cached pyobjc_framework_LocalAuthenticationEmbeddedUI-10.1-py2.py3-none-any.whl (3.4 kB)
# Collecting pyobjc-framework-AVKit==10.1
#   Using cached pyobjc_framework_AVKit-10.1-cp36-abi3-macosx_10_9_x86_64.whl (8.3 kB)
# Collecting pyobjc-framework-PreferencePanes==10.1
#   Using cached pyobjc_framework_PreferencePanes-10.1-py2.py3-none-any.whl (4.3 kB)
# Collecting pyobjc-framework-SearchKit==10.1
#   Using cached pyobjc_framework_SearchKit-10.1-py2.py3-none-any.whl (3.3 kB)
# Collecting pyobjc-framework-PassKit==10.1
#   Using cached pyobjc_framework_PassKit-10.1-cp36-abi3-macosx_10_9_x86_64.whl (9.9 kB)
# Collecting pyobjc-framework-FileProviderUI==10.1
#   Using cached pyobjc_framework_FileProviderUI-10.1-py2.py3-none-any.whl (3.2 kB)
# Collecting pyobjc-framework-SceneKit==10.1
#   Using cached pyobjc_framework_SceneKit-10.1-cp36-abi3-macosx_10_9_x86_64.whl (22 kB)
# Collecting pyobjc-framework-Quartz==10.1
#   Using cached pyobjc_framework_Quartz-10.1-cp39-cp39-macosx_10_9_universal2.whl (230 kB)
# Collecting pyobjc-framework-NetworkExtension==10.1
#   Using cached pyobjc_framework_NetworkExtension-10.1-cp36-abi3-macosx_10_9_x86_64.whl (11 kB)
# Collecting pyobjc-framework-CoreLocation==10.1
#   Using cached pyobjc_framework_CoreLocation-10.1-cp36-abi3-macosx_10_9_x86_64.whl (9.6 kB)
# Collecting pyobjc-framework-Virtualization==10.1
#   Using cached pyobjc_framework_Virtualization-10.1-cp36-abi3-macosx_10_9_x86_64.whl (8.1 kB)
# Collecting pyobjc-framework-Collaboration==10.1
#   Using cached pyobjc_framework_Collaboration-10.1-py2.py3-none-any.whl (4.5 kB)
# Collecting pyobjc-framework-SecurityInterface==10.1
#   Using cached pyobjc_framework_SecurityInterface-10.1-cp36-abi3-macosx_10_9_x86_64.whl (7.6 kB)
# Collecting pyobjc-framework-SystemConfiguration==10.1
#   Using cached pyobjc_framework_SystemConfiguration-10.1-cp36-abi3-macosx_10_9_x86_64.whl (17 kB)
# Collecting pyobjc-framework-DiscRecording==10.1
#   Downloading pyobjc_framework_DiscRecording-10.1-cp36-abi3-macosx_10_9_x86_64.whl (12 kB)
# Collecting pyobjc-framework-iTunesLibrary==10.1
#   Using cached pyobjc_framework_iTunesLibrary-10.1-py2.py3-none-any.whl (4.7 kB)
# Collecting pyobjc-framework-ImageCaptureCore==10.1
#   Using cached pyobjc_framework_ImageCaptureCore-10.1-cp36-abi3-macosx_10_9_x86_64.whl (12 kB)
# Collecting pyobjc-framework-AppleScriptKit==10.1
#   Using cached pyobjc_framework_AppleScriptKit-10.1-py2.py3-none-any.whl (3.9 kB)
# Collecting pyobjc-framework-HealthKit==10.1
#   Downloading pyobjc_framework_HealthKit-10.1-cp36-abi3-macosx_10_9_x86_64.whl (15 kB)
# Collecting pyobjc-framework-ExceptionHandling==10.1
#   Using cached pyobjc_framework_ExceptionHandling-10.1-py2.py3-none-any.whl (6.8 kB)
# Collecting pyobjc-framework-AVFoundation==10.1
#   Using cached pyobjc_framework_AVFoundation-10.1-cp36-abi3-macosx_10_9_x86_64.whl (52 kB)
# Collecting pyobjc-framework-MediaPlayer==10.1
#   Using cached pyobjc_framework_MediaPlayer-10.1-py2.py3-none-any.whl (6.1 kB)
# Collecting pyobjc-framework-Cocoa==10.1
#   Using cached pyobjc_framework_Cocoa-10.1-cp39-cp39-macosx_10_9_universal2.whl (392 kB)
# Collecting pyobjc-framework-VideoSubscriberAccount==10.1
#   Using cached pyobjc_framework_VideoSubscriberAccount-10.1-py2.py3-none-any.whl (4.1 kB)
# Collecting pyobjc-framework-QuickLookThumbnailing==10.1
#   Using cached pyobjc_framework_QuickLookThumbnailing-10.1-py2.py3-none-any.whl (3.7 kB)
# Collecting pyobjc-framework-MetalFX==10.1
#   Using cached pyobjc_framework_MetalFX-10.1-cp36-abi3-macosx_10_9_x86_64.whl (7.0 kB)
# Collecting pyobjc-framework-InputMethodKit==10.1
#   Using cached pyobjc_framework_InputMethodKit-10.1-cp36-abi3-macosx_10_9_x86_64.whl (7.7 kB)
# Collecting pyobjc-framework-CoreBluetooth==10.1
#   Using cached pyobjc_framework_CoreBluetooth-10.1-cp36-abi3-macosx_10_9_x86_64.whl (10 kB)
# Collecting pyobjc-framework-GameController==10.1
#   Using cached pyobjc_framework_GameController-10.1-cp36-abi3-macosx_10_9_x86_64.whl (14 kB)
# Collecting pyobjc-framework-MediaToolbox==10.1
#   Using cached pyobjc_framework_MediaToolbox-10.1-cp36-abi3-macosx_10_9_x86_64.whl (8.4 kB)
# Collecting pyobjc-framework-MetalPerformanceShaders==10.1
#   Using cached pyobjc_framework_MetalPerformanceShaders-10.1-cp36-abi3-macosx_10_9_x86_64.whl (20 kB)
# Collecting pyobjc-framework-MailKit==10.1
#   Using cached pyobjc_framework_MailKit-10.1-py2.py3-none-any.whl (4.1 kB)
# Collecting pyobjc-framework-EventKit==10.1
#   Using cached pyobjc_framework_EventKit-10.1-py2.py3-none-any.whl (6.1 kB)
# Collecting pyobjc-framework-KernelManagement==10.1
#   Using cached pyobjc_framework_KernelManagement-10.1-py2.py3-none-any.whl (3.3 kB)
# Collecting pyobjc-framework-Photos==10.1
#   Using cached pyobjc_framework_Photos-10.1-cp36-abi3-macosx_10_9_x86_64.whl (9.6 kB)
# Collecting pyobjc-framework-MLCompute==10.1
#   Using cached pyobjc_framework_MLCompute-10.1-py2.py3-none-any.whl (6.1 kB)
# Collecting pyobjc-framework-GameCenter==10.1
#   Using cached pyobjc_framework_GameCenter-10.1-cp36-abi3-macosx_10_9_x86_64.whl (12 kB)
# Collecting pyobjc-framework-CoreData==10.1
#   Using cached pyobjc_framework_CoreData-10.1-cp36-abi3-macosx_10_9_x86_64.whl (13 kB)
# Collecting pyobjc-framework-ScreenTime==10.1
#   Using cached pyobjc_framework_ScreenTime-10.1-py2.py3-none-any.whl (3.2 kB)
# Collecting pyobjc-framework-Intents==10.1
#   Using cached pyobjc_framework_Intents-10.1-cp36-abi3-macosx_10_9_x86_64.whl (22 kB)
# Collecting pyobjc-framework-BackgroundAssets==10.1
#   Using cached pyobjc_framework_BackgroundAssets-10.1-cp36-abi3-macosx_10_9_x86_64.whl (7.2 kB)
# Collecting pyobjc-framework-SecurityFoundation==10.1
#   Using cached pyobjc_framework_SecurityFoundation-10.1-py2.py3-none-any.whl (3.3 kB)
# Collecting pyobjc-framework-InstantMessage==10.1
#   Using cached pyobjc_framework_InstantMessage-10.1-py2.py3-none-any.whl (5.2 kB)
# Collecting pyobjc-framework-Symbols==10.1
#   Using cached pyobjc_framework_Symbols-10.1-py2.py3-none-any.whl (2.8 kB)
# Collecting pyobjc-framework-DataDetection==10.1
#   Using cached pyobjc_framework_DataDetection-10.1-py2.py3-none-any.whl (3.0 kB)
# Collecting pyobjc-framework-Network==10.1
#   Using cached pyobjc_framework_Network-10.1-cp36-abi3-macosx_10_9_x86_64.whl (14 kB)
# Collecting pyobjc-framework-FinderSync==10.1
#   Using cached pyobjc_framework_FinderSync-10.1-py2.py3-none-any.whl (4.5 kB)
# Collecting pyobjc-framework-SharedWithYou==10.1
#   Using cached pyobjc_framework_SharedWithYou-10.1-cp36-abi3-macosx_10_9_x86_64.whl (6.5 kB)
# Collecting pyobjc-framework-Social==10.1
#   Using cached pyobjc_framework_Social-10.1-py2.py3-none-any.whl (4.0 kB)
# Collecting pyobjc-framework-ExternalAccessory==10.1
#   Using cached pyobjc_framework_ExternalAccessory-10.1-cp36-abi3-macosx_10_9_x86_64.whl (6.7 kB)
# Collecting pyobjc-framework-IOBluetoothUI==10.1
#   Using cached pyobjc_framework_IOBluetoothUI-10.1-py2.py3-none-any.whl (3.7 kB)
# Collecting pyobjc-framework-ReplayKit==10.1
#   Using cached pyobjc_framework_ReplayKit-10.1-cp36-abi3-macosx_10_9_x86_64.whl (7.3 kB)
# Collecting pyobjc-framework-AuthenticationServices==10.1
#   Using cached pyobjc_framework_AuthenticationServices-10.1-cp36-abi3-macosx_10_9_x86_64.whl (12 kB)
# Collecting pyobjc-framework-ModelIO==10.1
#   Using cached pyobjc_framework_ModelIO-10.1-cp36-abi3-macosx_10_9_x86_64.whl (15 kB)
# Collecting pyobjc-framework-DictionaryServices==10.1
#   Using cached pyobjc_framework_DictionaryServices-10.1-py2.py3-none-any.whl (3.5 kB)
# Collecting pyobjc-framework-OSAKit==10.1
#   Using cached pyobjc_framework_OSAKit-10.1-py2.py3-none-any.whl (3.7 kB)
# Collecting pyobjc-framework-Contacts==10.1
#   Using cached pyobjc_framework_Contacts-10.1-cp36-abi3-macosx_10_9_x86_64.whl (9.3 kB)
# Collecting pyobjc-framework-PHASE==10.1
#   Using cached pyobjc_framework_PHASE-10.1-py2.py3-none-any.whl (5.0 kB)
# Collecting pyobjc-framework-CloudKit==10.1
#   Using cached pyobjc_framework_CloudKit-10.1-py2.py3-none-any.whl (9.3 kB)
# Collecting pyobjc-framework-SensitiveContentAnalysis==10.1
#   Using cached pyobjc_framework_SensitiveContentAnalysis-10.1-py2.py3-none-any.whl (3.4 kB)
# Collecting pyobjc-framework-AVRouting==10.1
#   Using cached pyobjc_framework_AVRouting-10.1-cp36-abi3-macosx_10_9_x86_64.whl (6.0 kB)
# Collecting pyobjc-framework-CoreServices==10.1
#   Using cached pyobjc_framework_CoreServices-10.1-cp36-abi3-macosx_10_9_x86_64.whl (37 kB)
# Collecting pyobjc-framework-CoreMediaIO==10.1
#   Using cached pyobjc_framework_CoreMediaIO-10.1-cp36-abi3-macosx_10_9_x86_64.whl (13 kB)
# Collecting pyobjc-framework-CoreSpotlight==10.1
#   Using cached pyobjc_framework_CoreSpotlight-10.1-cp36-abi3-macosx_10_9_x86_64.whl (7.2 kB)
# Collecting pyobjc-framework-InstallerPlugins==10.1
#   Using cached pyobjc_framework_InstallerPlugins-10.1-py2.py3-none-any.whl (4.3 kB)
# Collecting pyobjc-framework-PushKit==10.1
#   Using cached pyobjc_framework_PushKit-10.1-cp36-abi3-macosx_10_9_x86_64.whl (6.0 kB)
# Collecting pyobjc-framework-MediaAccessibility==10.1
#   Using cached pyobjc_framework_MediaAccessibility-10.1-py2.py3-none-any.whl (4.1 kB)
# Collecting pyobjc-framework-IOBluetooth==10.1
#   Using cached pyobjc_framework_IOBluetooth-10.1-cp36-abi3-macosx_10_9_x86_64.whl (37 kB)
# Collecting pyobjc-framework-CalendarStore==10.1
#   Using cached pyobjc_framework_CalendarStore-10.1-py2.py3-none-any.whl (4.9 kB)
# Collecting pyobjc-core==10.1
#   Using cached pyobjc_core-10.1-cp39-cp39-macosx_10_9_universal2.whl (753 kB)
# Collecting pyobjc-framework-LaunchServices==10.1
#   Using cached pyobjc_framework_LaunchServices-10.1-py2.py3-none-any.whl (3.5 kB)
# Collecting pyobjc-framework-AppleScriptObjC==10.1
#   Using cached pyobjc_framework_AppleScriptObjC-10.1-py2.py3-none-any.whl (4.0 kB)
# Collecting pyobjc-framework-DiscRecordingUI==10.1
#   Using cached pyobjc_framework_DiscRecordingUI-10.1-py2.py3-none-any.whl (4.6 kB)
# Collecting pyobjc-framework-SafariServices==10.1
#   Using cached pyobjc_framework_SafariServices-10.1-cp36-abi3-macosx_10_9_x86_64.whl (5.8 kB)
# Collecting pyobjc-framework-NotificationCenter==10.1
#   Using cached pyobjc_framework_NotificationCenter-10.1-cp36-abi3-macosx_10_9_x86_64.whl (7.2 kB)
# Collecting pyobjc-framework-Speech==10.1
#   Using cached pyobjc_framework_Speech-10.1-cp36-abi3-macosx_10_9_x86_64.whl (7.6 kB)
# Collecting pyobjc-framework-SpriteKit==10.1
#   Using cached pyobjc_framework_SpriteKit-10.1-cp39-cp39-macosx_10_9_universal2.whl (17 kB)
# Collecting pyobjc-framework-VideoToolbox==10.1
#   Using cached pyobjc_framework_VideoToolbox-10.1-cp36-abi3-macosx_10_9_x86_64.whl (10 kB)
# Collecting pyobjc-framework-CoreText==10.1
#   Using cached pyobjc_framework_CoreText-10.1-cp39-cp39-macosx_10_9_universal2.whl (32 kB)
# Collecting pyobjc-framework-Cinematic==10.1
#   Using cached pyobjc_framework_Cinematic-10.1-py2.py3-none-any.whl (3.8 kB)
# Collecting pyobjc-framework-CoreMIDI==10.1
#   Using cached pyobjc_framework_CoreMIDI-10.1-cp36-abi3-macosx_10_9_x86_64.whl (13 kB)
# Collecting pyobjc-framework-AddressBook==10.1
#   Using cached pyobjc_framework_AddressBook-10.1-cp36-abi3-macosx_10_9_x86_64.whl (11 kB)
# Collecting pyobjc-framework-CoreMotion==10.1
#   Using cached pyobjc_framework_CoreMotion-10.1-cp39-cp39-macosx_10_9_universal2.whl (10 kB)
# Collecting pyobjc-framework-DVDPlayback==10.1
#   Using cached pyobjc_framework_DVDPlayback-10.1-py2.py3-none-any.whl (8.1 kB)
# Collecting pyobjc-framework-MapKit==10.1
#   Using cached pyobjc_framework_MapKit-10.1-cp36-abi3-macosx_10_9_x86_64.whl (15 kB)
# Collecting pyobjc-framework-CallKit==10.1
#   Using cached pyobjc_framework_CallKit-10.1-py2.py3-none-any.whl (4.5 kB)
# Collecting pyobjc-framework-CryptoTokenKit==10.1
#   Using cached pyobjc_framework_CryptoTokenKit-10.1-cp36-abi3-macosx_10_9_x86_64.whl (9.4 kB)
# Collecting pyobjc-framework-SoundAnalysis==10.1
#   Using cached pyobjc_framework_SoundAnalysis-10.1-py2.py3-none-any.whl (3.6 kB)
# Collecting pyobjc-framework-FSEvents==10.1
#   Using cached pyobjc_framework_FSEvents-10.1-cp36-abi3-macosx_10_9_x86_64.whl (9.1 kB)
# Collecting pyobjc-framework-MediaLibrary==10.1
#   Using cached pyobjc_framework_MediaLibrary-10.1-py2.py3-none-any.whl (3.9 kB)
# Collecting pyobjc-framework-ExecutionPolicy==10.1
#   Using cached pyobjc_framework_ExecutionPolicy-10.1-py2.py3-none-any.whl (3.3 kB)
# Collecting pyobjc-framework-LocalAuthentication==10.1
#   Using cached pyobjc_framework_LocalAuthentication-10.1-py2.py3-none-any.whl (5.5 kB)
# Collecting pyobjc-framework-LinkPresentation==10.1
#   Using cached pyobjc_framework_LinkPresentation-10.1-py2.py3-none-any.whl (3.3 kB)
# Collecting pyobjc-framework-DiskArbitration==10.1
#   Using cached pyobjc_framework_DiskArbitration-10.1-py2.py3-none-any.whl (4.6 kB)
# Collecting pyobjc-framework-UniformTypeIdentifiers==10.1
#   Using cached pyobjc_framework_UniformTypeIdentifiers-10.1-py2.py3-none-any.whl (4.4 kB)
# Collecting pyobjc-framework-SystemExtensions==10.1
#   Downloading pyobjc_framework_SystemExtensions-10.1-cp36-abi3-macosx_10_9_x86_64.whl (6.4 kB)
# Collecting pyobjc-framework-StoreKit==10.1
#   Using cached pyobjc_framework_StoreKit-10.1-cp36-abi3-macosx_10_9_x86_64.whl (8.9 kB)
# Collecting pyobjc-framework-AudioVideoBridging==10.1
#   Using cached pyobjc_framework_AudioVideoBridging-10.1-cp39-cp39-macosx_10_9_universal2.whl (11 kB)
# Collecting pyobjc-framework-ContactsUI==10.1
#   Using cached pyobjc_framework_ContactsUI-10.1-cp36-abi3-macosx_10_9_x86_64.whl (5.8 kB)
# Collecting pyobjc-framework-LatentSemanticMapping==10.1
#   Downloading pyobjc_framework_LatentSemanticMapping-10.1-py2.py3-none-any.whl (5.2 kB)
# Collecting pyobjc-framework-GameplayKit==10.1
#   Using cached pyobjc_framework_GameplayKit-10.1-cp36-abi3-macosx_10_9_x86_64.whl (9.4 kB)
# Collecting pyobjc-framework-Accessibility==10.1
#   Using cached pyobjc_framework_Accessibility-10.1-cp36-abi3-macosx_10_9_x86_64.whl (7.3 kB)
# Collecting pyobjc-framework-Security==10.1
#   Using cached pyobjc_framework_Security-10.1-cp39-cp39-macosx_10_9_universal2.whl (41 kB)
# Collecting pyobjc-framework-IOSurface==10.1
#   Using cached pyobjc_framework_IOSurface-10.1-py2.py3-none-any.whl (4.6 kB)
# Collecting pyobjc-framework-OpenDirectory==10.1
#   Using cached pyobjc_framework_OpenDirectory-10.1-py2.py3-none-any.whl (11 kB)
# Collecting pyobjc-framework-Automator==10.1
#   Using cached pyobjc_framework_Automator-10.1-cp36-abi3-macosx_10_9_x86_64.whl (7.8 kB)
# Collecting pyobjc-framework-DeviceCheck==10.1
#   Using cached pyobjc_framework_DeviceCheck-10.1-py2.py3-none-any.whl (3.3 kB)
# Collecting pyobjc-framework-ScreenSaver==10.1
#   Using cached pyobjc_framework_ScreenSaver-10.1-cp36-abi3-macosx_10_9_x86_64.whl (6.4 kB)
# Collecting pyobjc-framework-NetFS==10.1
#   Using cached pyobjc_framework_NetFS-10.1-py2.py3-none-any.whl (3.8 kB)
# Collecting pyobjc-framework-GameKit==10.1
#   Using cached pyobjc_framework_GameKit-10.1-cp36-abi3-macosx_10_9_x86_64.whl (15 kB)
# Collecting pyobjc-framework-Metal==10.1
#   Using cached pyobjc_framework_Metal-10.1-cp36-abi3-macosx_10_9_x86_64.whl (38 kB)
# Collecting pyobjc-framework-ShazamKit==10.1
#   Downloading pyobjc_framework_ShazamKit-10.1-cp39-cp39-macosx_10_9_universal2.whl (9.1 kB)
# Collecting pyobjc-framework-libxpc==10.1
#   Using cached pyobjc_framework_libxpc-10.1-cp39-cp39-macosx_10_9_universal2.whl (19 kB)
# Collecting pyobjc-framework-Accounts==10.1
#   Using cached pyobjc_framework_Accounts-10.1-py2.py3-none-any.whl (4.6 kB)
# Collecting pyobjc-framework-MultipeerConnectivity==10.1
#   Using cached pyobjc_framework_MultipeerConnectivity-10.1-cp36-abi3-macosx_10_9_x86_64.whl (8.9 kB)
# Collecting pyobjc-framework-CoreHaptics==10.1
#   Using cached pyobjc_framework_CoreHaptics-10.1-py2.py3-none-any.whl (4.7 kB)
# Collecting pyobjc-framework-ThreadNetwork==10.1
#   Using cached pyobjc_framework_ThreadNetwork-10.1-py2.py3-none-any.whl (3.3 kB)
# Collecting pyobjc-framework-UserNotifications==10.1
#   Using cached pyobjc_framework_UserNotifications-10.1-cp36-abi3-macosx_10_9_x86_64.whl (7.4 kB)
# Collecting pyobjc-framework-FileProvider==10.1
#   Using cached pyobjc_framework_FileProvider-10.1-cp39-cp39-macosx_10_9_universal2.whl (17 kB)
# Collecting pyobjc-framework-Vision==10.1
#   Using cached pyobjc_framework_Vision-10.1-cp36-abi3-macosx_10_9_x86_64.whl (14 kB)
# Collecting pyobjc-framework-OSLog==10.1
#   Using cached pyobjc_framework_OSLog-10.1-cp36-abi3-macosx_10_9_x86_64.whl (5.8 kB)
# Collecting pyobjc-framework-IntentsUI==10.1
#   Using cached pyobjc_framework_IntentsUI-10.1-cp39-cp39-macosx_10_9_universal2.whl (10.0 kB)
# Collecting pyobjc-framework-ScreenCaptureKit==10.1
#   Using cached pyobjc_framework_ScreenCaptureKit-10.1-cp39-cp39-macosx_10_9_universal2.whl (11 kB)
# Collecting pyobjc-framework-ClassKit==10.1
#   Using cached pyobjc_framework_ClassKit-10.1-cp36-abi3-macosx_10_9_x86_64.whl (6.3 kB)
# Collecting pyobjc-framework-ExtensionKit==10.1
#   Using cached pyobjc_framework_ExtensionKit-10.1-cp36-abi3-macosx_10_9_x86_64.whl (5.8 kB)
# Collecting pyobjc-framework-PencilKit==10.1
#   Downloading pyobjc_framework_PencilKit-10.1-py2.py3-none-any.whl (3.3 kB)
# Collecting pyobjc-framework-CFNetwork==10.1
#   Using cached pyobjc_framework_CFNetwork-10.1-cp36-abi3-macosx_10_9_x86_64.whl (14 kB)
# Collecting pyobjc-framework-SharedWithYouCore==10.1
#   Using cached pyobjc_framework_SharedWithYouCore-10.1-cp36-abi3-macosx_10_9_x86_64.whl (6.1 kB)
# Collecting pyobjc-framework-CoreWLAN==10.1
#   Using cached pyobjc_framework_CoreWLAN-10.1-cp36-abi3-macosx_10_9_x86_64.whl (8.2 kB)
# Collecting pyobjc-framework-ApplicationServices==10.1
#   Using cached pyobjc_framework_ApplicationServices-10.1-cp39-cp39-macosx_10_9_universal2.whl (33 kB)
# Collecting pyobjc-framework-CoreAudio==10.1
#   Using cached pyobjc_framework_CoreAudio-10.1-cp39-cp39-macosx_10_9_universal2.whl (38 kB)
# Collecting pyobjc-framework-AdSupport==10.1
#   Using cached pyobjc_framework_AdSupport-10.1-py2.py3-none-any.whl (3.0 kB)
# Installing collected packages: pyobjc-core, pyobjc-framework-Cocoa, pyobjc-framework-WebKit, pyobjc-framework-Virtualization, pyobjc-framework-VideoSubscriberAccount, pyobjc-framework-UserNotifications, pyobjc-framework-UniformTypeIdentifiers, pyobjc-framework-ThreadNetwork, pyobjc-framework-SystemExtensions, pyobjc-framework-SystemConfiguration, pyobjc-framework-Symbols, pyobjc-framework-StoreKit, pyobjc-framework-Speech, pyobjc-framework-SoundAnalysis, pyobjc-framework-Social, pyobjc-framework-ShazamKit, pyobjc-framework-SharedWithYouCore, pyobjc-framework-ServiceManagement, pyobjc-framework-Security, pyobjc-framework-ScriptingBridge, pyobjc-framework-ScreenTime, pyobjc-framework-ScreenSaver, pyobjc-framework-SafariServices, pyobjc-framework-ReplayKit, pyobjc-framework-Quartz, pyobjc-framework-PushKit, pyobjc-framework-PreferencePanes, pyobjc-framework-PhotosUI, pyobjc-framework-Photos, pyobjc-framework-PencilKit, pyobjc-framework-PassKit, pyobjc-framework-OSAKit, pyobjc-framework-OpenDirectory, pyobjc-framework-NotificationCenter, pyobjc-framework-NetworkExtension, pyobjc-framework-Network, pyobjc-framework-NetFS, pyobjc-framework-NaturalLanguage, pyobjc-framework-MultipeerConnectivity, pyobjc-framework-MLCompute, pyobjc-framework-MetricKit, pyobjc-framework-Metal, pyobjc-framework-MediaToolbox, pyobjc-framework-MediaAccessibility, pyobjc-framework-MailKit, pyobjc-framework-libxpc, pyobjc-framework-libdispatch, pyobjc-framework-LatentSemanticMapping, pyobjc-framework-KernelManagement, pyobjc-framework-iTunesLibrary, pyobjc-framework-IOSurface, pyobjc-framework-IOBluetooth, pyobjc-framework-Intents, pyobjc-framework-InstallerPlugins, pyobjc-framework-InputMethodKit, pyobjc-framework-ImageCaptureCore, pyobjc-framework-HealthKit, pyobjc-framework-GameController, pyobjc-framework-GameCenter, pyobjc-framework-FSEvents, pyobjc-framework-FinderSync, pyobjc-framework-FileProvider, pyobjc-framework-ExternalAccessory, pyobjc-framework-ExtensionKit, pyobjc-framework-ExecutionPolicy, pyobjc-framework-ExceptionHandling, pyobjc-framework-EventKit, pyobjc-framework-DVDPlayback, pyobjc-framework-DiskArbitration, pyobjc-framework-DiscRecording, pyobjc-framework-DeviceCheck, pyobjc-framework-DataDetection, pyobjc-framework-CryptoTokenKit, pyobjc-framework-CoreWLAN, pyobjc-framework-CoreSpotlight, pyobjc-framework-CoreMotion, pyobjc-framework-CoreML, pyobjc-framework-CoreMIDI, pyobjc-framework-CoreMediaIO, pyobjc-framework-CoreMedia, pyobjc-framework-CoreLocation, pyobjc-framework-CoreHaptics, pyobjc-framework-CoreData, pyobjc-framework-CoreBluetooth, pyobjc-framework-CoreAudio, pyobjc-framework-Contacts, pyobjc-framework-ColorSync, pyobjc-framework-Collaboration, pyobjc-framework-ClassKit, pyobjc-framework-CFNetwork, pyobjc-framework-CallKit, pyobjc-framework-CalendarStore, pyobjc-framework-BusinessChat, pyobjc-framework-BackgroundAssets, pyobjc-framework-AVRouting, pyobjc-framework-Automator, pyobjc-framework-AutomaticAssessmentConfiguration, pyobjc-framework-AuthenticationServices, pyobjc-framework-AudioVideoBridging, pyobjc-framework-AppTrackingTransparency, pyobjc-framework-AppleScriptObjC, pyobjc-framework-AppleScriptKit, pyobjc-framework-AdSupport, pyobjc-framework-AdServices, pyobjc-framework-AddressBook, pyobjc-framework-Accounts, pyobjc-framework-Vision, pyobjc-framework-VideoToolbox, pyobjc-framework-UserNotificationsUI, pyobjc-framework-SyncServices, pyobjc-framework-SpriteKit, pyobjc-framework-SharedWithYou, pyobjc-framework-SensitiveContentAnalysis, pyobjc-framework-SecurityInterface, pyobjc-framework-SecurityFoundation, pyobjc-framework-ScreenCaptureKit, pyobjc-framework-SceneKit, pyobjc-framework-SafetyKit, pyobjc-framework-QuickLookThumbnailing, pyobjc-framework-OSLog, pyobjc-framework-ModelIO, pyobjc-framework-MetalPerformanceShaders, pyobjc-framework-MetalKit, pyobjc-framework-MetalFX, pyobjc-framework-MediaLibrary, pyobjc-framework-MapKit, pyobjc-framework-LocalAuthentication, pyobjc-framework-LinkPresentation, pyobjc-fram ...
#   Attempting uninstall: pyobjc-core
#     Found existing installation: pyobjc-core 8.5
#     Uninstalling pyobjc-core-8.5:
#       Successfully uninstalled pyobjc-core-8.5
#   Attempting uninstall: pyobjc-framework-Cocoa
#     Found existing installation: pyobjc-framework-Cocoa 8.5
#     Uninstalling pyobjc-framework-Cocoa-8.5:
#       Successfully uninstalled pyobjc-framework-Cocoa-8.5
#   Attempting uninstall: pyobjc-framework-FSEvents
#     Found existing installation: pyobjc-framework-FSEvents 8.5
#     Uninstalling pyobjc-framework-FSEvents-8.5:
#       Successfully uninstalled pyobjc-framework-FSEvents-8.5
#   Attempting uninstall: pyobjc-framework-CoreServices
#     Found existing installation: pyobjc-framework-CoreServices 8.5
#     Uninstalling pyobjc-framework-CoreServices-8.5:
#       Successfully uninstalled pyobjc-framework-CoreServices-8.5
# Successfully installed pyobjc-10.1 pyobjc-core-10.1 pyobjc-framework-AVFoundation-10.1 pyobjc-framework-AVKit-10.1 pyobjc-framework-AVRouting-10.1 pyobjc-framework-Accessibility-10.1 pyobjc-framework-Accounts-10.1 pyobjc-framework-AdServices-10.1 pyobjc-framework-AdSupport-10.1 pyobjc-framework-AddressBook-10.1 pyobjc-framework-AppTrackingTransparency-10.1 pyobjc-framework-AppleScriptKit-10.1 pyobjc-framework-AppleScriptObjC-10.1 pyobjc-framework-ApplicationServices-10.1 pyobjc-framework-AudioVideoBridging-10.1 pyobjc-framework-AuthenticationServices-10.1 pyobjc-framework-AutomaticAssessmentConfiguration-10.1 pyobjc-framework-Automator-10.1 pyobjc-framework-BackgroundAssets-10.1 pyobjc-framework-BusinessChat-10.1 pyobjc-framework-CFNetwork-10.1 pyobjc-framework-CalendarStore-10.1 pyobjc-framework-CallKit-10.1 pyobjc-framework-Cinematic-10.1 pyobjc-framework-ClassKit-10.1 pyobjc-framework-CloudKit-10.1 pyobjc-framework-Cocoa-10.1 pyobjc-framework-Collaboration-10.1 pyobjc-framework-ColorSync-10.1 pyobjc-framework-Contacts-10.1 pyobjc-framework-ContactsUI-10.1 pyobjc-framework-CoreAudio-10.1 pyobjc-framework-CoreAudioKit-10.1 pyobjc-framework-CoreBluetooth-10.1 pyobjc-framework-CoreData-10.1 pyobjc-framework-CoreHaptics-10.1 pyobjc-framework-CoreLocation-10.1 pyobjc-framework-CoreMIDI-10.1 pyobjc-framework-CoreML-10.1 pyobjc-framework-CoreMedia-10.1 pyobjc-framework-CoreMediaIO-10.1 pyobjc-framework-CoreMotion-10.1 pyobjc-framework-CoreServices-10.1 pyobjc-framework-CoreSpotlight-10.1 pyobjc-framework-CoreText-10.1 pyobjc-framework-CoreWLAN-10.1 pyobjc-framework-CryptoTokenKit-10.1 pyobjc-framework-DVDPlayback-10.1 pyobjc-framework-DataDetection-10.1 pyobjc-framework-DeviceCheck-10.1 pyobjc-framework-DictionaryServices-10.1 pyobjc-framework-DiscRecording-10.1 pyobjc-framework-DiscRecordingUI-10.1 pyobjc-framework-DiskArbitration-10.1 pyobjc-framework-EventKit-10.1 pyobjc-framework-ExceptionHandling-10.1 pyobjc-framework-ExecutionPolicy-10.1 pyobjc-framework-ExtensionKit-10.1 pyobjc-framework-ExternalAccessory-10.1 pyobjc-framework-FSEvents-10.1 pyobjc-framework-FileProvider-10.1 pyobjc-framework-FileProviderUI-10.1 pyobjc-framework-FinderSync-10.1 pyobjc-framework-GameCenter-10.1 pyobjc-framework-GameController-10.1 pyobjc-framework-GameKit-10.1 pyobjc-framework-GameplayKit-10.1 pyobjc-framework-HealthKit-10.1 pyobjc-framework-IOBluetooth-10.1 pyobjc-framework-IOBluetoothUI-10.1 pyobjc-framework-IOSurface-10.1 pyobjc-framework-ImageCaptureCore-10.1 pyobjc-framework-InputMethodKit-10.1 pyobjc-framework-InstallerPlugins-10.1 pyobjc-framework-InstantMessage-10.1 pyobjc-framework-Intents-10.1 pyobjc-framework-IntentsUI-10.1 pyobjc-framework-KernelManagement-10.1 pyobjc-framework-LatentSemanticMapping-10.1 pyobjc-framework-LaunchServices-10.1 pyobjc-framework-LinkPresentation-10.1 pyobjc-framework-LocalAuthentication-10.1 pyobjc-framework-LocalAuthenticationEmbeddedUI-10.1 pyobjc-framework-MLCompute-10.1 pyobjc-framework-MailKit-10.1 pyobjc-framework-MapKit-10.1 pyobjc-framework-MediaAccessibility-10.1 pyobjc-framework-MediaLibrary-10.1 pyobjc-framework-MediaPlayer-10.1 pyobjc-framework-MediaToolbox-10.1 pyobjc-framework-Metal-10.1 pyobjc-framework-MetalFX-10.1 pyobjc-framework-MetalKit-10.1 pyobjc-framework-MetalPerformanceShaders-10.1 pyobjc-framework-MetalPerformanceShadersGraph-10.1 pyobjc-framework-MetricKit-10.1 pyobjc-framework-ModelIO-10.1 pyobjc-framework-MultipeerConnectivity-10.1 pyobjc-framework-NaturalLanguage-10.1 pyobjc-framework-NetFS-10.1 pyobjc-framework-Network-10.1 pyobjc-framework-NetworkExtension-10.1 pyobjc-framework-NotificationCenter-10.1 pyobjc-framework-OSAKit-10.1 pyobjc-framework-OSLog-10.1 pyobjc-framework-OpenDirectory-10.1 pyobjc-framework-PHASE-10.1 pyobjc-framework-PassKit-10.1 pyobjc-framework-PencilKit-10.1 pyobjc-framework-Photos-10.1 pyobjc-framework-PhotosUI-10.1 pyobjc-framework-PreferencePanes-10.1 pyobjc-framework-PushKit-10.1 pyobjc-framework-Quartz-10.1 pyobjc-framework-QuickLookThumbnailin ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import speech_recognition as sr
import pyttsx3 
 
# Initialize the recognizer 
r = sr.Recognizer() 
 
# Function to convert text to
# speech
def SpeakText(command):
     
    # Initialize the engine
    engine = pyttsx3.init()
    engine.say(command) 
    engine.runAndWait()
     
     
# Loop infinitely for user to
# speak
 
while(1):    
     
    # Exception handling to handle
    # exceptions at the runtime
    try:
         
        # use the microphone as source for input.
        with sr.Microphone() as source2:
             
            # wait for a second to let the recognizer
            # adjust the energy threshold based on
            # the surrounding noise level 
            r.adjust_for_ambient_noise(source2, duration=0.2)
             
            #listens for the user's input 
            audio2 = r.listen(source2)
             
            # Using google to recognize audio
            MyText = r.recognize_google(audio2)
            MyText = MyText.lower()
 
            print("Did you say ",MyText)
            SpeakText(MyText)
             
    except sr.RequestError as e:
        print("Could not request results; {0}".format(e))
         
    except sr.UnknownValueError:
        print("unknown error occurred")
# Out:
# Could not import the PyAudio C module 'pyaudio._portaudio'.
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/speech_recognition/__init__.py in get_pyaudio()
#     107         try:
# --> 108             import pyaudio
#     109         except ImportError:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pyaudio/__init__.py in <module>
#     110 try:
# --> 111     import pyaudio._portaudio as pa
#     112 except ImportError:
#
# ImportError: dlopen(/Users/yashraj/opt/anaconda3/lib/python3.9/site-packages/pyaudio/_portaudio.cpython-39-darwin.so, 0x0002): symbol not found in flat namespace '_PaMacCore_SetupChannelMap'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# /var/folders/q6/8yscqmqs1cn_0n8z28c8vlw80000gn/T/ipykernel_12188/1640763856.py in <module>
#      25
#      26         # use the microphone as source for input.
# ---> 27         with sr.Microphone() as source2:
#      28
#      29             # wait for a second to let the recognizer
#
# ~/opt/anaconda3/lib/python3.9/site-packages/speech_recognition/__init__.py in __init__(self, device_index, sample_rate, chunk_size)
#      78
#      79         # set up PyAudio
# ---> 80         self.pyaudio_module = self.get_pyaudio()
#      81         audio = self.pyaudio_module.PyAudio()
#      82         try:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/speech_recognition/__init__.py in get_pyaudio()
#     108             import pyaudio
#     109         except ImportError:
# --> 110             raise AttributeError("Could not find PyAudio; check installation")
#     111         from distutils.version import LooseVersion
#     112         if LooseVersion(pyaudio.__version__) < LooseVersion("0.2.11"):
#
# AttributeError: Could not find PyAudio; check installation
